# %%
import os
import numpy as np
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()


import sys; sys.path.insert(0, "../utils/")
from data_utils import get_data_location, get_clinical_df, get_bluepoints_df, get_manual_severity_scores
from ml_pipeline import ModelEvaluation, highlight_max

DATA_PATH = get_data_location()

# %%
DIAGRAMS_PATH = os.path.join(DATA_PATH,"tda_entire_vid")

# List all files & directories
diagrams_files = os.listdir(DIAGRAMS_PATH)

# keep only files that end with .npy
diagrams_files = [x for x in diagrams_files if x.endswith(".pickle")]

len(diagrams_files)
# Out:
# 371

# %%
# Load the first file
diagrams = pd.read_pickle(os.path.join(DIAGRAMS_PATH, diagrams_files[0]))
diagrams.shape
#from gtda.plotting import plot_diagram
#plot_diagram(diagrams.squeeze())
# Out:
# (1, 258455, 3)

# %%
import pandas as pd

# Create a dataframe from digrams_files
df = pd.DataFrame(diagrams_files, columns=["file_name"])
# Split the file name to get the patient id
df["Patient ID"] = df["file_name"].apply(lambda x: x.split("_")[0])
# Split the file name to get the video name
df["video_name"] = df["file_name"].apply(lambda x: x.split("_")[1] + "_" + x.split("_")[2])
df["video_name"] = df["video_name"].apply(lambda x: x.split(".")[0])

# Load the diagrams into the dataframe
df["diagrams"] = df["file_name"].apply(lambda x: pd.read_pickle(os.path.join(DIAGRAMS_PATH, x)))

df.head()

# %%
clinical_data = get_clinical_df()

clinical_data = clinical_data[["Video ID", "clin_diagn#COVID19_pneumonia"]]
clinical_data.columns = ["Patient ID", "COVID19"]

df = pd.merge(df, clinical_data, on="Patient ID", how="left")
bp = get_bluepoints_df()
df = pd.merge(df, bp[["Bluepoint", "video_name"]], on="video_name", how="left")

df.head(1)

# %%
def featurize_diagram(diagram, representation):
    """Featurize diagrams with a given representation.
    
    Parameters
    ----------
    diagram : ndarray
        A persistence diagram in the gtda format.
    representation : object
        A representation object from gtda.diagrams.
        
    Returns
    -------
    X : ndarray
        A feature vector.
    """
    return representation.fit_transform(diagram).flatten()

# %%
# Import different featurizers
from gtda.diagrams import PersistenceEntropy
from gtda.diagrams import Amplitude
from gtda.diagrams import BettiCurve
from gtda.diagrams import PersistenceImage
from gtda.diagrams import NumberOfPoints

# Store all featurizer in a dict with name as key
featurizers = {"Persistence Entropy" : PersistenceEntropy(),
                "Number of Points" : NumberOfPoints(),
                "Wasserstein Amplitude" : Amplitude(metric='wasserstein'),
                "Bottleneck Amplitude" : Amplitude(metric='bottleneck'),
                "Landscape Amplitude" : Amplitude(metric='landscape'),
                "Betti Curves" : BettiCurve(n_bins=20),
                "Persistence Image" : PersistenceImage(n_bins=10, n_jobs=-1)
                
                }

# Apply the different featurizers to the diagrams and add them to the dataframe in separate columns
for name, featurizer in featurizers.items():
    print(f"Calculating {name}")
    df[name] = df["diagrams"].apply(lambda x: featurize_diagram(x, featurizer))
df.head(1)

# %% [markdown]
# ## Train models on features

# %%
Classifier = ModelEvaluation("classification")

# %%
featurizer_models = pd.DataFrame()
featurizer_models_all = pd.DataFrame()
featurizer_models_std = pd.DataFrame()
for name, featurizer in featurizers.items():
    print(f"Training model for {name}...")
    X = np.stack(df[name].values)
    y = df["COVID19"].values
    groups = df["Patient ID"].values
    
    scores, scores_mean, scores_std = Classifier.train_models(X, y, groups=groups, plot=False, return_std = True)
    scores = pd.concat([scores], keys=[name], names=['Featurizer'])
    scores_mean = pd.concat([scores_mean], keys=[name], names=['Featurizer'])
    scores_std = pd.concat([scores_std], keys=[name], names=['Featurizer'])
    
    featurizer_models_all = pd.concat([featurizer_models_all, scores])
    featurizer_models = pd.concat([featurizer_models, scores_mean])
    featurizer_models_std = pd.concat([featurizer_models_std, scores_std])
    
featurizer_models.groupby("Featurizer").mean().sort_values(by=["test_accuracy", "test_f1"], ascending=False).style.apply(highlight_max).format("{:.2f}")
# Out:
# Training model for Persistence Entropy...
# Training model for Number of Points...
# Training model for Wasserstein Amplitude...
# Training model for Bottleneck Amplitude...
# Training model for Landscape Amplitude...
# Training model for Betti Curves...
# Training model for Persistence Image...
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# <style type="text/css">
# #T_4a23d_row0_col0, #T_4a23d_row0_col2, #T_4a23d_row1_col3, #T_4a23d_row3_col1 {
#   color: green;
# }
# </style>
# <table id="T_4a23d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a23d_level0_col0" class="col_heading level0 col0" >test_accuracy</th>
#       <th id="T_4a23d_level0_col1" class="col_heading level0 col1" >test_sensitivity</th>
#       <th id="T_4a23d_level0_col2" class="col_heading level0 col2" >test_specificity</th>
#       <th id="T_4a23d_level0_col3" class="col_heading level0 col3" >test_f1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Featurizer</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a23d_level0_row0" class="row_heading level0 row0" >Persistence Image</th>
#       <td id="T_4a23d_row0_col0" class="data row0 col0" >0.59</td>
#       <td id="T_4a23d_row0_col1" class="data row0 col1" >0.64</td>
#       <td id="T_4a23d_row0_col2" class="data row0 col2" >0.54</td>
#       <td id="T_4a23d_row0_col3" class="data row0 col3" >0.62</td>
#     </tr>
#     <tr>
#       <th id="T_4a23d_level0_row1" class="row_heading level0 row1" >Betti Curves</th>
#       <td id="T_4a23d_row1_col0" class="data row1 col0" >0.58</td>
#       <td id="T_4a23d_row1_col1" class="data row1 col1" >0.66</td>
#       <td id="T_4a23d_row1_col2" class="data row1 col2" >0.49</td>
#       <td id="T_4a23d_row1_col3" class="data row1 col3" >0.63</td>
#     </tr>
#     <tr>
#       <th id="T_4a23d_level0_row2" class="row_heading level0 row2" >Persistence Entropy</th>
#       <td id="T_4a23d_row2_col0" class="data row2 col0" >0.54</td>
#       <td id="T_4a23d_row2_col1" class="data row2 col1" >0.63</td>
#       <td id="T_4a23d_row2_col2" class="data row2 col2" >0.45</td>
#       <td id="T_4a23d_row2_col3" class="data row2 col3" >0.59</td>
#     </tr>
#     <tr>
#       <th id="T_4a23d_level0_row3" class="row_heading level0 row3" >Bottleneck Amplitude</th>
#       <td id="T_4a23d_row3_col0" class="data row3 col0" >0.52</td>
#       <td id="T_4a23d_row3_col1" class="data row3 col1" >0.75</td>
#       <td id="T_4a23d_row3_col2" class="data row3 col2" >0.30</td>
#       <td id="T_4a23d_row3_col3" class="data row3 col3" >0.62</td>
#     </tr>
#     <tr>
#       <th id="T_4a23d_level0_row4" class="row_heading level0 row4" >Number of Points</th>
#       <td id="T_4a23d_row4_col0" class="data row4 col0" >0.52</td>
#       <td id="T_4a23d_row4_col1" class="data row4 col1" >0.65</td>
#       <td id="T_4a23d_row4_col2" class="data row4 col2" >0.40</td>
#       <td id="T_4a23d_row4_col3" class="data row4 col3" >0.59</td>
#     </tr>
#     <tr>
#       <th id="T_4a23d_level0_row5" class="row_heading level0 row5" >Wasserstein Amplitude</th>
#       <td id="T_4a23d_row5_col0" class="data row5 col0" >0.49</td>
#       <td id="T_4a23d_row5_col1" class="data row5 col1" >0.66</td>
#       <td id="T_4a23d_row5_col2" class="data row5 col2" >0.34</td>
#       <td id="T_4a23d_row5_col3" class="data row5 col3" >0.57</td>
#     </tr>
#     <tr>
#       <th id="T_4a23d_level0_row6" class="row_heading level0 row6" >Landscape Amplitude</th>
#       <td id="T_4a23d_row6_col0" class="data row6 col0" >0.48</td>
#       <td id="T_4a23d_row6_col1" class="data row6 col1" >0.71</td>
#       <td id="T_4a23d_row6_col2" class="data row6 col2" >0.24</td>
#       <td id="T_4a23d_row6_col3" class="data row6 col3" >0.59</td>
#     </tr>
#   </tbody>
# </table>

# %%
featurizer_models.groupby("Featurizer").mean().sort_values(by=["test_accuracy", "test_f1"], ascending=False).plot.bar(yerr=featurizer_models.groupby("Featurizer").std())
plt.legend(loc='lower right')

# %%
grouped = featurizer_models.groupby("Featurizer")
max_index = grouped["test_accuracy"].idxmax()
best_models = featurizer_models.loc[max_index].sort_values("test_accuracy", ascending=False)
best_models.index = best_models.reset_index().Featurizer + " (" + best_models.reset_index().model + ")"

best_models_std = featurizer_models_std.loc[max_index]
best_models_std.index = best_models_std.reset_index().Featurizer + " (" + best_models_std.reset_index().model + ")"
best_models_std = best_models_std.loc[best_models.index]

best_models.plot.bar()
plt.legend(loc='lower right')

best_models.style.apply(highlight_max).format("{:.2f}")
# Out:
# <style type="text/css">
# #T_3c5d7_row0_col0, #T_3c5d7_row0_col1, #T_3c5d7_row0_col2, #T_3c5d7_row0_col3 {
#   color: green;
# }
# </style>
# <table id="T_3c5d7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c5d7_level0_col0" class="col_heading level0 col0" >test_accuracy</th>
#       <th id="T_3c5d7_level0_col1" class="col_heading level0 col1" >test_sensitivity</th>
#       <th id="T_3c5d7_level0_col2" class="col_heading level0 col2" >test_specificity</th>
#       <th id="T_3c5d7_level0_col3" class="col_heading level0 col3" >test_f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c5d7_level0_row0" class="row_heading level0 row0" >Persistence Image (RF)</th>
#       <td id="T_3c5d7_row0_col0" class="data row0 col0" >0.64</td>
#       <td id="T_3c5d7_row0_col1" class="data row0 col1" >0.74</td>
#       <td id="T_3c5d7_row0_col2" class="data row0 col2" >0.53</td>
#       <td id="T_3c5d7_row0_col3" class="data row0 col3" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_3c5d7_level0_row1" class="row_heading level0 row1" >Betti Curves (LR)</th>
#       <td id="T_3c5d7_row1_col0" class="data row1 col0" >0.59</td>
#       <td id="T_3c5d7_row1_col1" class="data row1 col1" >0.68</td>
#       <td id="T_3c5d7_row1_col2" class="data row1 col2" >0.48</td>
#       <td id="T_3c5d7_row1_col3" class="data row1 col3" >0.64</td>
#     </tr>
#     <tr>
#       <th id="T_3c5d7_level0_row2" class="row_heading level0 row2" >Bottleneck Amplitude (RF)</th>
#       <td id="T_3c5d7_row2_col0" class="data row2 col0" >0.55</td>
#       <td id="T_3c5d7_row2_col1" class="data row2 col1" >0.63</td>
#       <td id="T_3c5d7_row2_col2" class="data row2 col2" >0.48</td>
#       <td id="T_3c5d7_row2_col3" class="data row2 col3" >0.60</td>
#     </tr>
#     <tr>
#       <th id="T_3c5d7_level0_row3" class="row_heading level0 row3" >Persistence Entropy (RF)</th>
#       <td id="T_3c5d7_row3_col0" class="data row3 col0" >0.55</td>
#       <td id="T_3c5d7_row3_col1" class="data row3 col1" >0.58</td>
#       <td id="T_3c5d7_row3_col2" class="data row3 col2" >0.52</td>
#       <td id="T_3c5d7_row3_col3" class="data row3 col3" >0.57</td>
#     </tr>
#     <tr>
#       <th id="T_3c5d7_level0_row4" class="row_heading level0 row4" >Number of Points (SVM)</th>
#       <td id="T_3c5d7_row4_col0" class="data row4 col0" >0.54</td>
#       <td id="T_3c5d7_row4_col1" class="data row4 col1" >0.69</td>
#       <td id="T_3c5d7_row4_col2" class="data row4 col2" >0.39</td>
#       <td id="T_3c5d7_row4_col3" class="data row4 col3" >0.61</td>
#     </tr>
#     <tr>
#       <th id="T_3c5d7_level0_row5" class="row_heading level0 row5" >Landscape Amplitude (RF)</th>
#       <td id="T_3c5d7_row5_col0" class="data row5 col0" >0.51</td>
#       <td id="T_3c5d7_row5_col1" class="data row5 col1" >0.60</td>
#       <td id="T_3c5d7_row5_col2" class="data row5 col2" >0.44</td>
#       <td id="T_3c5d7_row5_col3" class="data row5 col3" >0.56</td>
#     </tr>
#     <tr>
#       <th id="T_3c5d7_level0_row6" class="row_heading level0 row6" >Wasserstein Amplitude (RF)</th>
#       <td id="T_3c5d7_row6_col0" class="data row6 col0" >0.51</td>
#       <td id="T_3c5d7_row6_col1" class="data row6 col1" >0.55</td>
#       <td id="T_3c5d7_row6_col2" class="data row6 col2" >0.45</td>
#       <td id="T_3c5d7_row6_col3" class="data row6 col3" >0.54</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Make latex
latex = best_models.applymap(lambda x: f"{x:.2f}") + " $_{\pm " + best_models_std.applymap(lambda x: f"{x:.2f}") + "}$"
print(latex.to_latex(escape=False))
# Out:
# \begin{tabular}{lllll}
# \toprule
# {} &       test_accuracy &    test_sensitivity &    test_specificity &             test_f1 \\
# \midrule
# Persistence Image (RF)     &  0.64 $_{\pm 0.07}$ &  0.74 $_{\pm 0.09}$ &  0.53 $_{\pm 0.18}$ &  0.68 $_{\pm 0.07}$ \\
# Betti Curves (LR)          &  0.59 $_{\pm 0.06}$ &  0.68 $_{\pm 0.07}$ &  0.48 $_{\pm 0.13}$ &  0.64 $_{\pm 0.04}$ \\
# Bottleneck Amplitude (RF)  &  0.55 $_{\pm 0.06}$ &  0.63 $_{\pm 0.11}$ &  0.48 $_{\pm 0.09}$ &  0.60 $_{\pm 0.04}$ \\
# Persistence Entropy (RF)   &  0.55 $_{\pm 0.11}$ &  0.58 $_{\pm 0.14}$ &  0.52 $_{\pm 0.12}$ &  0.57 $_{\pm 0.14}$ \\
# Number of Points (SVM)     &  0.54 $_{\pm 0.07}$ &  0.69 $_{\pm 0.19}$ &  0.39 $_{\pm 0.17}$ &  0.61 $_{\pm 0.05}$ \\
# Landscape Amplitude (RF)   &  0.51 $_{\pm 0.04}$ &  0.60 $_{\pm 0.09}$ &  0.44 $_{\pm 0.12}$ &  0.56 $_{\pm 0.05}$ \\
# Wasserstein Amplitude (RF) &  0.51 $_{\pm 0.10}$ &  0.55 $_{\pm 0.17}$ &  0.45 $_{\pm 0.18}$ &  0.54 $_{\pm 0.14}$ \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Patient Level

# %%
# Aggregate feature vectors across each Patient using the mean
patient_level_df = df.groupby("Patient ID")[list(featurizers.keys())].mean().reset_index()
# Add back Covid variable
patient_level_df = pd.merge(df.groupby("Patient ID")["COVID19"].first().reset_index(), patient_level_df)
patient_level_df.head(1)

# %%
featurizer_models_patients = pd.DataFrame()
featurizer_models_all_patients = pd.DataFrame()
featurizer_models_std_patients = pd.DataFrame()
for name, featurizer in featurizers.items():
    print(f"Training model for {name}...")
    X = np.stack(patient_level_df[name].values)
    y = patient_level_df["COVID19"].values
    
    scores, scores_mean, scores_std = Classifier.train_models(X, y, plot=False, return_std = True)
    scores = pd.concat([scores], keys=[name], names=['Featurizer'])
    scores_mean = pd.concat([scores_mean], keys=[name], names=['Featurizer'])
    scores_std = pd.concat([scores_std], keys=[name], names=['Featurizer'])
    
    featurizer_models_all_patients = pd.concat([featurizer_models_all_patients, scores])
    featurizer_models_patients = pd.concat([featurizer_models_patients, scores_mean])
    featurizer_models_std_patients = pd.concat([featurizer_models_std_patients, scores_std])
    
#featurizer_models.style.apply(highlight_max).format("{:.2f}")
# Out:
# Training model for Persistence Entropy...
# Training model for Number of Points...
# Training model for Wasserstein Amplitude...
# Training model for Bottleneck Amplitude...
# Training model for Landscape Amplitude...
# Training model for Betti Curves...
# Training model for Persistence Image...

# %%
grouped = featurizer_models_patients.groupby("Featurizer")
max_index = grouped["test_accuracy"].idxmax()
best_models = featurizer_models_patients.loc[max_index].sort_values("test_accuracy", ascending=False)
best_models.index = best_models.reset_index().Featurizer + " (" + best_models.reset_index().model + ")"

best_models_std = featurizer_models_std_patients.loc[max_index]
best_models_std.index = best_models_std.reset_index().Featurizer + " (" + best_models_std.reset_index().model + ")"
best_models_std = best_models_std.loc[best_models.index]

best_models.plot.bar()
plt.legend(loc='lower right')

best_models.style.apply(highlight_max).format("{:.2f}")
# Out:
# <style type="text/css">
# #T_a040c_row0_col0, #T_a040c_row0_col1, #T_a040c_row0_col2, #T_a040c_row0_col3, #T_a040c_row1_col2 {
#   color: green;
# }
# </style>
# <table id="T_a040c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a040c_level0_col0" class="col_heading level0 col0" >test_accuracy</th>
#       <th id="T_a040c_level0_col1" class="col_heading level0 col1" >test_sensitivity</th>
#       <th id="T_a040c_level0_col2" class="col_heading level0 col2" >test_specificity</th>
#       <th id="T_a040c_level0_col3" class="col_heading level0 col3" >test_f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a040c_level0_row0" class="row_heading level0 row0" >Betti Curves (SVM)</th>
#       <td id="T_a040c_row0_col0" class="data row0 col0" >0.70</td>
#       <td id="T_a040c_row0_col1" class="data row0 col1" >0.70</td>
#       <td id="T_a040c_row0_col2" class="data row0 col2" >0.70</td>
#       <td id="T_a040c_row0_col3" class="data row0 col3" >0.70</td>
#     </tr>
#     <tr>
#       <th id="T_a040c_level0_row1" class="row_heading level0 row1" >Persistence Image (LR)</th>
#       <td id="T_a040c_row1_col0" class="data row1 col0" >0.68</td>
#       <td id="T_a040c_row1_col1" class="data row1 col1" >0.66</td>
#       <td id="T_a040c_row1_col2" class="data row1 col2" >0.70</td>
#       <td id="T_a040c_row1_col3" class="data row1 col3" >0.67</td>
#     </tr>
#     <tr>
#       <th id="T_a040c_level0_row2" class="row_heading level0 row2" >Persistence Entropy (LR)</th>
#       <td id="T_a040c_row2_col0" class="data row2 col0" >0.57</td>
#       <td id="T_a040c_row2_col1" class="data row2 col1" >0.51</td>
#       <td id="T_a040c_row2_col2" class="data row2 col2" >0.63</td>
#       <td id="T_a040c_row2_col3" class="data row2 col3" >0.51</td>
#     </tr>
#     <tr>
#       <th id="T_a040c_level0_row3" class="row_heading level0 row3" >Number of Points (LR)</th>
#       <td id="T_a040c_row3_col0" class="data row3 col0" >0.56</td>
#       <td id="T_a040c_row3_col1" class="data row3 col1" >0.52</td>
#       <td id="T_a040c_row3_col2" class="data row3 col2" >0.60</td>
#       <td id="T_a040c_row3_col3" class="data row3 col3" >0.52</td>
#     </tr>
#     <tr>
#       <th id="T_a040c_level0_row4" class="row_heading level0 row4" >Wasserstein Amplitude (LR)</th>
#       <td id="T_a040c_row4_col0" class="data row4 col0" >0.54</td>
#       <td id="T_a040c_row4_col1" class="data row4 col1" >0.58</td>
#       <td id="T_a040c_row4_col2" class="data row4 col2" >0.50</td>
#       <td id="T_a040c_row4_col3" class="data row4 col3" >0.55</td>
#     </tr>
#     <tr>
#       <th id="T_a040c_level0_row5" class="row_heading level0 row5" >Bottleneck Amplitude (SVM)</th>
#       <td id="T_a040c_row5_col0" class="data row5 col0" >0.48</td>
#       <td id="T_a040c_row5_col1" class="data row5 col1" >0.61</td>
#       <td id="T_a040c_row5_col2" class="data row5 col2" >0.33</td>
#       <td id="T_a040c_row5_col3" class="data row5 col3" >0.53</td>
#     </tr>
#     <tr>
#       <th id="T_a040c_level0_row6" class="row_heading level0 row6" >Landscape Amplitude (RF)</th>
#       <td id="T_a040c_row6_col0" class="data row6 col0" >0.44</td>
#       <td id="T_a040c_row6_col1" class="data row6 col1" >0.39</td>
#       <td id="T_a040c_row6_col2" class="data row6 col2" >0.50</td>
#       <td id="T_a040c_row6_col3" class="data row6 col3" >0.40</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Make latex
latex = best_models.applymap(lambda x: f"{x:.2f}") + " $_{\pm " + best_models_std.applymap(lambda x: f"{x:.2f}") + "}$"
print(latex.to_latex(escape=False))
# Out:
# \begin{tabular}{lllll}
# \toprule
# {} &       test_accuracy &    test_sensitivity &    test_specificity &             test_f1 \\
# \midrule
# Betti Curves (SVM)         &  0.70 $_{\pm 0.09}$ &  0.70 $_{\pm 0.16}$ &  0.70 $_{\pm 0.18}$ &  0.70 $_{\pm 0.09}$ \\
# Persistence Image (LR)     &  0.68 $_{\pm 0.09}$ &  0.66 $_{\pm 0.22}$ &  0.70 $_{\pm 0.22}$ &  0.67 $_{\pm 0.12}$ \\
# Persistence Entropy (LR)   &  0.57 $_{\pm 0.18}$ &  0.51 $_{\pm 0.35}$ &  0.63 $_{\pm 0.14}$ &  0.51 $_{\pm 0.28}$ \\
# Number of Points (LR)      &  0.56 $_{\pm 0.15}$ &  0.52 $_{\pm 0.32}$ &  0.60 $_{\pm 0.15}$ &  0.52 $_{\pm 0.23}$ \\
# Wasserstein Amplitude (LR) &  0.54 $_{\pm 0.20}$ &  0.58 $_{\pm 0.29}$ &  0.50 $_{\pm 0.20}$ &  0.55 $_{\pm 0.23}$ \\
# Bottleneck Amplitude (SVM) &  0.48 $_{\pm 0.19}$ &  0.61 $_{\pm 0.29}$ &  0.33 $_{\pm 0.20}$ &  0.53 $_{\pm 0.23}$ \\
# Landscape Amplitude (RF)   &  0.44 $_{\pm 0.06}$ &  0.39 $_{\pm 0.18}$ &  0.50 $_{\pm 0.12}$ &  0.40 $_{\pm 0.15}$ \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Severity Scores

# %%
sev_scores = get_manual_severity_scores()
sev_scores = sev_scores[["Severity Score", "video_name"]]
sev_scores["Severity Score"] = sev_scores["Severity Score"].astype(int)
df = pd.merge(df, sev_scores, on="video_name")
# Out:
# Number of discarded rows: 8
# /tmp/ipykernel_18611/1783145124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sev_scores["Severity Score"] = sev_scores["Severity Score"].astype(int)

# %%
import importlib
import ml_pipeline
importlib.reload(ml_pipeline)
from ml_pipeline import ModelEvaluation


Multi_Classifier = ModelEvaluation(mode="classification_multi_label")

# %%
featurizer_models = pd.DataFrame()
featurizer_models_all = pd.DataFrame()
featurizer_models_std = pd.DataFrame()
for name, featurizer in featurizers.items():
    print(f"Training model for {name}...")
    X = np.stack(df[name].values)
    y = df["Severity Score"].values
    groups = df["Patient ID"].values
    
    scores, scores_mean, scores_std = Multi_Classifier.train_models(X, y, groups=groups, plot=False, return_std = True)
    scores = pd.concat([scores], keys=[name], names=['Featurizer'])
    scores_mean = pd.concat([scores_mean], keys=[name], names=['Featurizer'])
    scores_std = pd.concat([scores_std], keys=[name], names=['Featurizer'])
    
    featurizer_models_all = pd.concat([featurizer_models_all, scores])
    featurizer_models = pd.concat([featurizer_models, scores_mean])
    featurizer_models_std = pd.concat([featurizer_models_std, scores_std])

featurizer_models.groupby("Featurizer").mean().sort_values(by=["test_f1"], ascending=False).style.apply(highlight_max).format("{:.2f}")
# Out:
# Training model for Persistence Entropy...
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Training model for Number of Points...
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Training model for Wasserstein Amplitude...
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Training model for Bottleneck Amplitude...
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Training model for Landscape Amplitude...
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Training model for Betti Curves...
# Training model for Persistence Image...
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /scratch_net/gnarf/mrichte/conda_envs/DL4LUS/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <style type="text/css">
# #T_746b7_row0_col0, #T_746b7_row0_col1, #T_746b7_row0_col2, #T_746b7_row0_col3 {
#   color: green;
# }
# </style>
# <table id="T_746b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_746b7_level0_col0" class="col_heading level0 col0" >test_accuracy</th>
#       <th id="T_746b7_level0_col1" class="col_heading level0 col1" >test_f1</th>
#       <th id="T_746b7_level0_col2" class="col_heading level0 col2" >test_recall</th>
#       <th id="T_746b7_level0_col3" class="col_heading level0 col3" >test_precision</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Featurizer</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_746b7_level0_row0" class="row_heading level0 row0" >Wasserstein Amplitude</th>
#       <td id="T_746b7_row0_col0" class="data row0 col0" >0.34</td>
#       <td id="T_746b7_row0_col1" class="data row0 col1" >0.30</td>
#       <td id="T_746b7_row0_col2" class="data row0 col2" >0.34</td>
#       <td id="T_746b7_row0_col3" class="data row0 col3" >0.32</td>
#     </tr>
#     <tr>
#       <th id="T_746b7_level0_row1" class="row_heading level0 row1" >Betti Curves</th>
#       <td id="T_746b7_row1_col0" class="data row1 col0" >0.31</td>
#       <td id="T_746b7_row1_col1" class="data row1 col1" >0.29</td>
#       <td id="T_746b7_row1_col2" class="data row1 col2" >0.31</td>
#       <td id="T_746b7_row1_col3" class="data row1 col3" >0.31</td>
#     </tr>
#     <tr>
#       <th id="T_746b7_level0_row2" class="row_heading level0 row2" >Persistence Entropy</th>
#       <td id="T_746b7_row2_col0" class="data row2 col0" >0.34</td>
#       <td id="T_746b7_row2_col1" class="data row2 col1" >0.29</td>
#       <td id="T_746b7_row2_col2" class="data row2 col2" >0.34</td>
#       <td id="T_746b7_row2_col3" class="data row2 col3" >0.28</td>
#     </tr>
#     <tr>
#       <th id="T_746b7_level0_row3" class="row_heading level0 row3" >Persistence Image</th>
#       <td id="T_746b7_row3_col0" class="data row3 col0" >0.27</td>
#       <td id="T_746b7_row3_col1" class="data row3 col1" >0.26</td>
#       <td id="T_746b7_row3_col2" class="data row3 col2" >0.27</td>
#       <td id="T_746b7_row3_col3" class="data row3 col3" >0.27</td>
#     </tr>
#     <tr>
#       <th id="T_746b7_level0_row4" class="row_heading level0 row4" >Number of Points</th>
#       <td id="T_746b7_row4_col0" class="data row4 col0" >0.30</td>
#       <td id="T_746b7_row4_col1" class="data row4 col1" >0.26</td>
#       <td id="T_746b7_row4_col2" class="data row4 col2" >0.30</td>
#       <td id="T_746b7_row4_col3" class="data row4 col3" >0.24</td>
#     </tr>
#     <tr>
#       <th id="T_746b7_level0_row5" class="row_heading level0 row5" >Landscape Amplitude</th>
#       <td id="T_746b7_row5_col0" class="data row5 col0" >0.29</td>
#       <td id="T_746b7_row5_col1" class="data row5 col1" >0.25</td>
#       <td id="T_746b7_row5_col2" class="data row5 col2" >0.29</td>
#       <td id="T_746b7_row5_col3" class="data row5 col3" >0.23</td>
#     </tr>
#     <tr>
#       <th id="T_746b7_level0_row6" class="row_heading level0 row6" >Bottleneck Amplitude</th>
#       <td id="T_746b7_row6_col0" class="data row6 col0" >0.29</td>
#       <td id="T_746b7_row6_col1" class="data row6 col1" >0.24</td>
#       <td id="T_746b7_row6_col2" class="data row6 col2" >0.29</td>
#       <td id="T_746b7_row6_col3" class="data row6 col3" >0.25</td>
#     </tr>
#   </tbody>
# </table>

# %%
featurizer_models.groupby("Featurizer").mean().sort_values(by=["test_f1"], ascending=False).plot.bar(yerr=featurizer_models.groupby("Featurizer").std())
plt.legend(loc='lower right')

# %%
grouped = featurizer_models.groupby("Featurizer")
max_index = grouped["test_accuracy"].idxmax()
best_models = featurizer_models.loc[max_index].sort_values("test_f1", ascending=False)
best_models.index = best_models.reset_index().Featurizer + " (" + best_models.reset_index().model + ")"

best_models_std = featurizer_models_std.loc[max_index]
best_models_std.index = best_models_std.reset_index().Featurizer + " (" + best_models_std.reset_index().model + ")"
best_models_std = best_models_std.loc[best_models.index]

best_models.plot.bar()
plt.legend(loc='lower right')

best_models.style.apply(highlight_max).format("{:.2f}")
# Out:
# <style type="text/css">
# #T_16e7c_row0_col1, #T_16e7c_row1_col3, #T_16e7c_row5_col0, #T_16e7c_row5_col2 {
#   color: green;
# }
# </style>
# <table id="T_16e7c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16e7c_level0_col0" class="col_heading level0 col0" >test_accuracy</th>
#       <th id="T_16e7c_level0_col1" class="col_heading level0 col1" >test_f1</th>
#       <th id="T_16e7c_level0_col2" class="col_heading level0 col2" >test_recall</th>
#       <th id="T_16e7c_level0_col3" class="col_heading level0 col3" >test_precision</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16e7c_level0_row0" class="row_heading level0 row0" >Betti Curves (LR)</th>
#       <td id="T_16e7c_row0_col0" class="data row0 col0" >0.33</td>
#       <td id="T_16e7c_row0_col1" class="data row0 col1" >0.31</td>
#       <td id="T_16e7c_row0_col2" class="data row0 col2" >0.33</td>
#       <td id="T_16e7c_row0_col3" class="data row0 col3" >0.31</td>
#     </tr>
#     <tr>
#       <th id="T_16e7c_level0_row1" class="row_heading level0 row1" >Wasserstein Amplitude (SVM)</th>
#       <td id="T_16e7c_row1_col0" class="data row1 col0" >0.34</td>
#       <td id="T_16e7c_row1_col1" class="data row1 col1" >0.30</td>
#       <td id="T_16e7c_row1_col2" class="data row1 col2" >0.34</td>
#       <td id="T_16e7c_row1_col3" class="data row1 col3" >0.35</td>
#     </tr>
#     <tr>
#       <th id="T_16e7c_level0_row2" class="row_heading level0 row2" >Bottleneck Amplitude (RF)</th>
#       <td id="T_16e7c_row2_col0" class="data row2 col0" >0.31</td>
#       <td id="T_16e7c_row2_col1" class="data row2 col1" >0.30</td>
#       <td id="T_16e7c_row2_col2" class="data row2 col2" >0.31</td>
#       <td id="T_16e7c_row2_col3" class="data row2 col3" >0.34</td>
#     </tr>
#     <tr>
#       <th id="T_16e7c_level0_row3" class="row_heading level0 row3" >Landscape Amplitude (RF)</th>
#       <td id="T_16e7c_row3_col0" class="data row3 col0" >0.31</td>
#       <td id="T_16e7c_row3_col1" class="data row3 col1" >0.30</td>
#       <td id="T_16e7c_row3_col2" class="data row3 col2" >0.31</td>
#       <td id="T_16e7c_row3_col3" class="data row3 col3" >0.31</td>
#     </tr>
#     <tr>
#       <th id="T_16e7c_level0_row4" class="row_heading level0 row4" >Persistence Image (RF)</th>
#       <td id="T_16e7c_row4_col0" class="data row4 col0" >0.31</td>
#       <td id="T_16e7c_row4_col1" class="data row4 col1" >0.29</td>
#       <td id="T_16e7c_row4_col2" class="data row4 col2" >0.31</td>
#       <td id="T_16e7c_row4_col3" class="data row4 col3" >0.29</td>
#     </tr>
#     <tr>
#       <th id="T_16e7c_level0_row5" class="row_heading level0 row5" >Persistence Entropy (SVM)</th>
#       <td id="T_16e7c_row5_col0" class="data row5 col0" >0.35</td>
#       <td id="T_16e7c_row5_col1" class="data row5 col1" >0.29</td>
#       <td id="T_16e7c_row5_col2" class="data row5 col2" >0.35</td>
#       <td id="T_16e7c_row5_col3" class="data row5 col3" >0.27</td>
#     </tr>
#     <tr>
#       <th id="T_16e7c_level0_row6" class="row_heading level0 row6" >Number of Points (SVM)</th>
#       <td id="T_16e7c_row6_col0" class="data row6 col0" >0.31</td>
#       <td id="T_16e7c_row6_col1" class="data row6 col1" >0.25</td>
#       <td id="T_16e7c_row6_col2" class="data row6 col2" >0.31</td>
#       <td id="T_16e7c_row6_col3" class="data row6 col3" >0.23</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Make latex
latex = best_models.applymap(lambda x: f"{x:.2f}") + " $_{\pm " + best_models_std.applymap(lambda x: f"{x:.2f}") + "}$"
# Drop accuracy
latex = latex.drop("test_accuracy", axis=1)
# Drop all rows containing "Amplitude"
latex = latex[~latex.index.str.contains("Amplitude")]
print(latex.to_latex(escape=False))
# Out:
# \begin{tabular}{llll}
# \toprule
# {} &             test_f1 &         test_recall &      test_precision \\
# \midrule
# Betti Curves (LR)         &  0.31 $_{\pm 0.06}$ &  0.33 $_{\pm 0.04}$ &  0.31 $_{\pm 0.07}$ \\
# Persistence Image (RF)    &  0.29 $_{\pm 0.05}$ &  0.31 $_{\pm 0.04}$ &  0.29 $_{\pm 0.06}$ \\
# Persistence Entropy (SVM) &  0.29 $_{\pm 0.04}$ &  0.35 $_{\pm 0.06}$ &  0.27 $_{\pm 0.07}$ \\
# Number of Points (SVM)    &  0.25 $_{\pm 0.04}$ &  0.31 $_{\pm 0.06}$ &  0.23 $_{\pm 0.07}$ \\
# \bottomrule
# \end{tabular}
